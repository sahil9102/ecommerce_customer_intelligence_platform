# %%
# %run /Workspace/Users/sahil.prusty09@gmail.com/ecommerce_customer_intelligence_platform/env

# %%
# %sql
create volume if not exists ecommerce.bronze.data_file_container

# %%
# !pip install kaggle

# %%
# %sh
cd /Volumes/ecommerce/bronze/data_file_container
kaggle datasets download -d olistbr/brazilian-ecommerce

# %%
# %sh
cd /Volumes/ecommerce/bronze/data_file_container
unzip -o brazilian-ecommerce.zip
ls -lh

# %%
# %sh
cd /Volumes/ecommerce/bronze/data_file_container
rm -f brazilian-ecommerce.zip
ls -lh
