# %%
# %sql
use catalog ecommerce

# %%
from pyspark.sql.functions import *
import json

# %%
for job in (10001, 10002, 10003, 10004, 10005, 10006, 10007, 10008, 10009):
    with open(f"/Workspace/Users/sahil.prusty09@gmail.com/ecommerce_customer_intelligence_platform/jobs/bronze/{job}.json", "r") as job:
        job_details = json.load(job)
        job_details["partition"] = spark.range(1).select(date_format(current_timestamp(), "yyyyMMddHHmmssSSS").cast("bigint").alias('partition')).collect()[0]['partition']
        dbutils.notebook.run("/Workspace/Users/sahil.prusty09@gmail.com/ecommerce_customer_intelligence_platform/ETL/raw_to_bronze", 500, {"job_parameters" : json.dumps(job_details)})

# %%
# %sql
select seller_id, count(*) from bronze.vw_sellers group by 1 having count(*) > 1

# %%
# %sql
select order_id, payment_sequential, count(*) from ecommerce.bronze.vw_order_payments group by 1, 2 having count(*) > 1

# %%
# %sql
select order_id, order_item_id, count(*) from ecommerce.bronze.vw_order_items group by 1, 2 having count(*) > 1

# %%
# %sql
select geolocation_zip_code_prefix,geolocation_city,geolocation_state,geolocation_lat,geolocation_lng, count(*) from ecommerce.bronze.vw_geolocation group by 1,2,3,4,5 having count(*) > 1

# %%
# %sql
select customer_id, count(*) from ecommerce.bronze.vw_customers group by 1 having count(*) > 1

# %%
# %sql
select product_category_name, count(*) from ecommerce.bronze.vw_product_category_name_translation group by 1 having count(*) > 1

# %%
# %sql
select product_id, count(*) from ecommerce.bronze.vw_products group by 1 having count(*) > 1

# %%
# %sql
select review_id,order_id, count(*) from ecommerce.bronze.vw_order_reviews group by 1,2 having count(*) > 1

# %%
# %sql
select order_id, count(*) from ecommerce.bronze.vw_orders group by 1 having count(*) > 1
